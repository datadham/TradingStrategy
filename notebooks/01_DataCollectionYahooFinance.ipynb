# %%
# import librairies
import pandas as pd
import yfinance as yf
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_row',None)
pd.set_option('display.max_columns',None)

# %% [markdown]
# ## API period and timerange parameter
# > Use **"period"** instead of **start/end**
# valid periods: **1d**,**5d**,**1mo**,**3mo**,**6mo**,**1y**,**2y**,**5y**,**10y**,**ytd**,**max**
# (optional, default is '1mo')
# period = "ytd" (depuis le 01 janvier année modulé)
#
#
# > Fetch Data by interval (including intraday if period < 60 days)
# valid intervals: **1m**,**2m**,**5m**,**15m**,**30m**,**60m**,**90m**,**1h**,**1d**,**5d**,**1wk**,**1mo**,**3mo**(optional, default is '1d') interval = "1m",
#
#
# - full documentation : https://pypi.org/project/yfinance/

# %%
cours = 'BTC-EUR'
actif = yf.Ticker(cours)
hist = actif.history(period="max",interval='1d')

# %% [markdown]
# ## Asset definition

# %%
actif.info
# Out:
# {'name': 'Bitcoin',
#  'startDate': 1278979200,
#  'description': 'Bitcoin (BTC) is a cryptocurrency launched in 2010. Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,700,275. The last known price of Bitcoin is 67,136.17439756 USD and is up 0.41 over the last 24 hours. It is currently trading on 11047 active market(s) with $15,899,236,595.65 traded over the last 24 hours. More information can be found at https://bitcoin.org/.',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 61519.883,
#  'open': 61519.883,
#  'dayLow': 61478.383,
#  'dayHigh': 61882.992,
#  'regularMarketPreviousClose': 61519.883,
#  'regularMarketOpen': 61519.883,
#  'regularMarketDayLow': 61478.383,
#  'regularMarketDayHigh': 61882.992,
#  'volume': 14204839936,
#  'regularMarketVolume': 14204839936,
#  'averageVolume': 34573374341,
#  'averageVolume10days': 24262485737,
#  'averageDailyVolume10Day': 24262485737,
#  'marketCap': 1215475482624,
#  'fiftyTwoWeekLow': 22886.795,
#  'fiftyTwoWeekHigh': 67416.49,
#  'fiftyDayAverage': 60495.28,
#  'twoHundredDayAverage': 47870.098,
#  'currency': 'EUR',
#  'fromCurrency': 'BTC',
#  'toCurrency': 'EUR=X',
#  'lastMarket': 'CoinMarketCap',
#  'coinMarketCapLink': 'https://coinmarketcap.com/currencies/bitcoin',
#  'volume24Hr': 14204839936,
#  'volumeAllCurrencies': 14204839936,
#  'circulatingSupply': 19700328,
#  'exchange': 'CCC',
#  'quoteType': 'CRYPTOCURRENCY',
#  'symbol': 'BTC-EUR',
#  'underlyingSymbol': 'BTC-EUR',
#  'shortName': 'Bitcoin EUR',
#  'longName': 'Bitcoin EUR',
#  'firstTradeDateEpochUtc': 1410912000,
#  'timeZoneFullName': 'UTC',
#  'timeZoneShortName': 'UTC',
#  'uuid': 'fc83fd75-ef09-31da-803c-99606b2da1b9',
#  'messageBoardId': 'finmb_BTC_CCC',
#  'trailingPegRatio': None}

# %% [markdown]
# ## Get Top News of the asset

# %%
actif.news
# Out:
# [{'uuid': 'adf9be86-cca7-4c40-850f-885bbc5cc17f',
#   'title': 'CD rates today, May 19, 2024 (up to 5.15% APY)',
#   'publisher': 'Yahoo Personal Finance',
#   'link': 'https://finance.yahoo.com/personal-finance/cd-rates-today-sunday-may-19-2024-100023520.html',
#   'providerPublishTime': 1716112823,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ahgWOuX.I9DOBGc_O19Llg--~B/aD0zNDgwO3c9NTIyMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2024-04/7d70aad0-f2cc-11ee-a57f-6fb602e47ca5',
#      'width': 5220,
#      'height': 3480,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/t3pG0ArnTGrwDyl8VXPRdw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2024-04/7d70aad0-f2cc-11ee-a57f-6fb602e47ca5',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': 'a46c3c35-17e7-47bd-9669-679d72a690d3',
#   'title': 'Savings interest rates today, May 19, 2024 (best accounts offering 5.15% APY)',
#   'publisher': 'Yahoo Personal Finance',
#   'link': 'https://finance.yahoo.com/personal-finance/savings-interest-rates-today-sunday-may-19-2024-100015934.html',
#   'providerPublishTime': 1716112815,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/oAihfnWqTlZj2PWlE7P2HA--~B/aD00MDAwO3c9NjAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-images/2020-01/83572720-411f-11ea-9d72-2748648a96e7',
#      'width': 6000,
#      'height': 4000,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/0xNMZo0OmDBBg7XHycL6cw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-images/2020-01/83572720-411f-11ea-9d72-2748648a96e7',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '76d1b5d0-7614-4b85-9c90-087d1ad016f4',
#   'title': 'Mortgage rates today, May 19, 2024: Rates inch down but remain high overall',
#   'publisher': 'Yahoo Personal Finance',
#   'link': 'https://finance.yahoo.com/personal-finance/mortgage-rates-today-sunday-may-19-2024-100010941.html',
#   'providerPublishTime': 1716112810,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/1By0gWKZoNPeZRq3GmRYlg--~B/aD0xNzU1O3c9MzEyMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2024-04/6f016ae0-03e6-11ef-97ff-13785de87be3',
#      'width': 3120,
#      'height': 1755,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/fT1NI6xFC4Y2Cq_QTnmZ1g--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2024-04/6f016ae0-03e6-11ef-97ff-13785de87be3',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '48dca930-cfc7-31d1-af68-b8488333086e',
#   'title': 'Just How Worried Should You Be About Social Security Cuts? Not as Much as You Might Think.',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/48dca930-cfc7-31d1-af68-b8488333086e/just-how-worried-should-you.html',
#   'providerPublishTime': 1716112800,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ijwVUhb7uWUdwqBPPyQN7g--~B/aD05MjE7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/8badae6b2c3670c5ee96b39afdd18c2d',
#      'width': 1400,
#      'height': 921,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/Fj3tlEuUoaTZq_SfmF_7uQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/8badae6b2c3670c5ee96b39afdd18c2d',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '6404bfd1-3883-36db-9d35-ea1f6bde538f',
#   'title': '‘Socialistic’ London has lost its mojo, says Wizz Air boss',
#   'publisher': 'The Telegraph',
#   'link': 'https://finance.yahoo.com/m/6404bfd1-3883-36db-9d35-ea1f6bde538f/%E2%80%98socialistic%E2%80%99-london-has-lost.html',
#   'providerPublishTime': 1716112800,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Sf_42T4I2K7pOmMS9UrdSQ--~B/aD03MDk7dz0xMTM1O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/the_telegraph_258/f8c067f02c69cb0b4b84b0bc8b9bf31d',
#      'width': 1135,
#      'height': 709,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/g4PY1MxQuzAgc_X4RqO.EQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/the_telegraph_258/f8c067f02c69cb0b4b84b0bc8b9bf31d',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['WZZZY']},
#  {'uuid': 'd8c39bf1-b321-3ed3-939f-71ac21ce1ec9',
#   'title': 'Surprise: Artificial Intelligence (AI) Might Already Be Used to Allocate Your Retirement Savings',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/d8c39bf1-b321-3ed3-939f-71ac21ce1ec9/surprise%3A-artificial.html',
#   'providerPublishTime': 1716112500,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/C38p7Olki9uDBzxGol.xkQ--~B/aD03Mzg7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/d901aaadc6ad792789d8671a38d3b712',
#      'width': 1400,
#      'height': 738,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/Iq16.MBR_LkNS22JRWXKqA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/d901aaadc6ad792789d8671a38d3b712',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['SCHW', 'MSFT', 'GOOG', 'BLK']},
#  {'uuid': '8b8db395-dfc4-3d5e-8e51-aa49695c8af1',
#   'title': 'Fore! Virtual golf spots open in downtown Canton with elevated food, unique settings',
#   'publisher': 'The Repository',
#   'link': 'https://finance.yahoo.com/m/8b8db395-dfc4-3d5e-8e51-aa49695c8af1/fore%21-virtual-golf-spots-open.html',
#   'providerPublishTime': 1716112455,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/tciI2EO8Hca5cmQjWcyaOQ--~B/aD0xMTQzO3c9MTE5OTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/the-repository/f9dc965291db14f235ea76470e8a89c1',
#      'width': 1199,
#      'height': 1143,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/r3Jq.I.XyeoHFy_t9AZcbw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/the-repository/f9dc965291db14f235ea76470e8a89c1',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '811a9c6b-5e96-3461-b683-e813899722f8',
#   'title': '3 High-Yield Dividend ETFs to Buy to Generate Passive Income',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/811a9c6b-5e96-3461-b683-e813899722f8/3-high-yield-dividend-etfs-to.html',
#   'providerPublishTime': 1716112260,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/zf8G3bUcDMcApJeOFoZh.w--~B/aD0xMzE1O3c9MjI4MDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/31868002a2b3de14c96c628ae50828da',
#      'width': 2280,
#      'height': 1315,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/vKMjtMybIb3TleFyHZS4qg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/31868002a2b3de14c96c628ae50828da',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC', 'JPM']}]

# %% [markdown]
# ## Get Asset Historical Value

# %%
hist.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-09-17 00:00:00+00:00  359.546204  361.468506  351.586884  355.957367
# 2014-09-18 00:00:00+00:00  355.588409  355.505402  319.789459  328.539368
# 2014-09-19 00:00:00+00:00  328.278503  330.936707  298.921021  307.761139
# 2014-09-20 00:00:00+00:00  307.665253  329.978180  303.931244  318.758972
# 2014-09-21 00:00:00+00:00  318.120514  321.504517  306.502197  310.632446
#
#                              Volume  Dividends  Stock Splits
# Date
# 2014-09-17 00:00:00+00:00  16389166        0.0           0.0
# 2014-09-18 00:00:00+00:00  26691849        0.0           0.0
# 2014-09-19 00:00:00+00:00  29560103        0.0           0.0
# 2014-09-20 00:00:00+00:00  28736826        0.0           0.0
# 2014-09-21 00:00:00+00:00  20702625        0.0           0.0

# %% [markdown]
# ### Stock Data Columns Explanation
#
# #### 1. Date
# - **Definition**: The specific date on which the stock data is recorded.
# - **Example**: `2014-09-17 00:00:00+00:00`
#
# #### 2. Open
# - **Definition**: The opening price of the stock at the start of the trading day.
# - **Example**: `359.55`
#
# #### 3. High
# - **Definition**: The highest price reached by the stock during the trading day.
# - **Example**: `361.47`
#
# #### 4. Low
# - **Definition**: The lowest price reached by the stock during the trading day.
# - **Example**: `351.59`
#
# #### 5. Close
# - **Definition**: The closing price of the stock at the end of the trading day.
# - **Example**: `355.96`
#
# #### 6. Volume
# - **Definition**: The total number of shares traded during the trading day.
# - **Example**: `16,389,166`
#
# #### 7. Dividends
# - **Definition**: The dividends paid to shareholders on that date, if any.
# - **Example**: `0.0`
#
# #### 8. Stock Splits
# - **Definition**: The occurrence of stock splits on that date, if any.
# - **Example**: `0.0`
#
# ---
#
# #### Additional Notes:
# - **Opening Price**: Indicates the first price at which a stock is traded upon the opening of an exchange on a given trading day.
# - **Highest and Lowest Prices**: Help to identify the range of trading prices within the day, providing insights into the stock's volatility.
# - **Closing Price**: Often used as a benchmark for the stock's daily performance and is crucial for historical comparisons.
# - **Trading Volume**: Reflects the total activity and liquidity of the stock; higher volumes can indicate higher interest and market activity.
# - **Dividends**: Represent a portion of the company's earnings distributed to shareholders. If zero, no dividends were paid on that date.
# - **Stock Splits**: Adjust the company's number of outstanding shares and the price per share, but do not affect the company's overall market capitalization.
